# %% [markdown]
# # Abalone Gender Prediction

# %% [markdown]
# **Objective**: Predict the gender of abalone from physical measurements.
# Data available from: https://archive.ics.uci.edu/ml/datasets/abalone
# <br><br>
# Data comes from an original (non-machine-learning) study:
# Warwick J Nash, Tracy L Sellers, Simon R Talbot, Andrew J Cawthorn and Wes B Ford (1994)
# "The Population Biology of Abalone (_Haliotis_ species) in Tasmania. I. Blacklip Abalone (_H. rubra_) from the North Coast and Islands of Bass Strait",
# Sea Fisheries Division, Technical Report No. 48 (ISSN 1034-3288)

# %% [markdown]
# ![Chart Image](https://user-images.githubusercontent.com/30188729/35762873-6c8726fe-0854-11e8-8bac-bcc6b5c9350c.png)

# %% [markdown]
# ## **Table of Contents**
#
# 1. [Import Data & Python Packages](#1-bullet) <br>
# 2. [Update Dataset](#2-bullet)<br>
# 3. [Exploratory Data Analysis](#3-bullet)<br>
#     * [3.1 Males vs Females](#3.1-bullet) <br>
#     * [3.2 Correlations assessment](#3.2-bullet) <br>
# 4. [Logistic Regression](#4-bullet) <br>
#     * [4.1 Hold-Out Testing & Logistic Model Assessment](#4.1-bullet) <br>
#     * [4.2 Out-of-sample test results](#4.4-bullet) <br>
# 6. [Alternate Approach 1 : Random Forest Estimation](#6-bullet) <br>
# 7. [Alternate Approach 2: Decision Tree](#7-bullet) <br>

# %% [markdown]
# ## 1. Import Data & Python Packages <a class="anchor" id="1-bullet"></a>

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns; sns.set(color_codes=True)
from sklearn.cluster import KMeans
color = sns.color_palette()
from IPython.core.display import display, HTML
# %matplotlib inline
# Out:
# C:\Users\sgus1\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
url_ab = 'https://raw.githubusercontent.com/sgus1318/Abalone_Gender/master/abalone.txt'
df = pd.read_csv(url_ab)

# %%
df.head()
# Out:
#   Gender  Length  Diameter  Height  Whole_Weight  Shucked_Weight  \
# 0      M   0.455     0.365   0.095         0.514           0.225
# 1      M   0.350     0.265   0.090         0.226           0.100
# 2      F   0.530     0.420   0.135         0.677           0.257
# 3      M   0.440     0.365   0.125         0.516           0.215
# 4      I   0.330     0.255   0.080         0.205           0.089
#
#    Viscera_Weight  Shell_Weight  Rings
# 0           0.101         0.150     15
# 1           0.049         0.070      7
# 2           0.141         0.210      9
# 3           0.114         0.155     10
# 4           0.040         0.055      7

# %%
df.describe()
# Out:
#         Length  Diameter   Height  Whole_Weight  Shucked_Weight  \
# count 4177.000  4177.000 4177.000      4177.000        4177.000
# mean     0.524     0.408    0.140         0.829           0.359
# std      0.120     0.099    0.042         0.490           0.222
# min      0.075     0.055    0.000         0.002           0.001
# 25%      0.450     0.350    0.115         0.442           0.186
# 50%      0.545     0.425    0.140         0.799           0.336
# 75%      0.615     0.480    0.165         1.153           0.502
# max      0.815     0.650    1.130         2.825           1.488
#
#        Viscera_Weight  Shell_Weight    Rings
# count        4177.000      4177.000 4177.000
# mean            0.181         0.239    9.934
# std             0.110         0.139    3.224
# min             0.001         0.002    1.000
# 25%             0.093         0.130    8.000
# 50%             0.171         0.234    9.000
# 75%             0.253         0.329   11.000
# max             0.760         1.005   29.000

# %% [markdown]
# ## 2. Update Dataset <a class="anchor" id="2-bullet"></a>

# %% [markdown]
# ### Remove obserations where gender = "I" (infant) and only focus on categorization of M/F for now.

# %%
df_mf=df[df.Gender != 'I'].copy()

# %% [markdown]
# ### Create Dummy for Female

# %%
df_final=pd.get_dummies(df_mf, columns=["Gender"])

# %%
df_final.head()
# Out:
#    Length  Diameter  Height  Whole_Weight  Shucked_Weight  Viscera_Weight  \
# 0   0.455     0.365   0.095         0.514           0.225           0.101
# 1   0.350     0.265   0.090         0.226           0.100           0.049
# 2   0.530     0.420   0.135         0.677           0.257           0.141
# 3   0.440     0.365   0.125         0.516           0.215           0.114
# 6   0.530     0.415   0.150         0.777           0.237           0.141
#
#    Shell_Weight  Rings  Gender_F  Gender_M
# 0         0.150     15         0         1
# 1         0.070      7         0         1
# 2         0.210      9         1         0
# 3         0.155     10         0         1
# 6         0.330     20         1         0

# %% [markdown]
# ## 3. Exploratory Data Analysis <a class="anchor" id="3-bullet"></a>

# %% [markdown]
# ### 3.1  Males vs Females

# %%
sns.countplot('Gender_M', data=df_final, color="darkturquoise")
plt.show()

# %% [markdown]
# There are more male abalones in our data than female, but not by too much.

# %%
df_pairplot = df_mf.drop(['Height', 'Whole_Weight','Shell_Weight','Rings'],axis=1, inplace=False)

# %%
sns.pairplot(data=df_pairplot,palette="pastel",hue='Gender')

# %%
import seaborn as sns

sns.set(style="whitegrid", palette="pastel", color_codes=True)

#Draw a nested violinplot and split the violins for easier comparison
plt.subplots(figsize=(17,14))
sns.violinplot(x="Rings", y="Length", hue="Gender_M", data=df_final, split=True,
               inner="quart")
sns.despine(left=True)

# %%
plt.figure(figsize=(15,8))
sns.kdeplot(df_mf["Diameter"][df_mf.Gender == 'M'], color="darkturquoise", shade=True)
sns.kdeplot(df_mf["Diameter"][df_mf.Gender == 'F'], color="lightcoral", shade=True)
plt.legend(['Male', 'Female'])
plt.title('Density Plot of Diameter for Male & Female Abalone')
plt.show()

# %% [markdown]
# ### 3.2 Assess Correlations of Continuous Variables <a class="anchor" id="3.2-bullet"></a>

# %%
corr = df_mf.corr()

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(17,14))
sns.heatmap(corr, annot=True,cmap="Blues")

# %% [markdown]
# ## 4. Logistic Regression <a class="anchor" id="4-bullet"></a>

# %% [markdown]
# ### 80-20 Split for Cross Validation

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_final, test_size=0.2)

# %%
cols=["Length", "Diameter", "Height","Whole_Weight","Shucked_Weight","Viscera_Weight","Shell_Weight","Rings"] 
X=train[cols]
y=train['Gender_M']

# %%
import statsmodels.api as sm
from scipy import stats
#stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# %%
logit_model=sm.Logit(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 6.759843
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Gender_M   No. Observations:                 2268
# Model:                          Logit   Df Residuals:                     2260
# Method:                           MLE   Df Model:                            7
# Date:                Sun, 04 Feb 2018   Pseudo R-squ.:                  -19.43
# Time:                        17:05:04   Log-Likelihood:                -15331.
# converged:                       True   LL-Null:                       -750.27
#                                         LLR p-value:                     1.000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Length             4.8430      2.092      2.315      0.021       0.742       8.944
# Diameter          -5.8924      2.749     -2.144      0.032     -11.280      -0.505
# Height             1.5902      2.443      0.651      0.515      -3.198       6.378
# Whole_Weight      -0.6908      0.821     -0.842      0.400      -2.299       0.918
# Shucked_Weight     2.7530      1.000      2.752      0.006       0.792       4.714
# Viscera_Weight    -2.6841      1.406     -1.909      0.056      -5.440       0.072
# Shell_Weight      -1.3893      1.256     -1.106      0.269      -3.851       1.072
# Rings              0.0259      0.018      1.455      0.146      -0.009       0.061
# ==================================================================================

# %% [markdown]
# ### Remove insignificant variables iteratively

# %%
cols2=["Length", "Diameter","Shucked_Weight","Viscera_Weight"] 
X2=train[cols2]
y2=train['Gender_M']

# %%
logit_model=sm.Logit(y2,X2)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 5.319423
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Gender_M   No. Observations:                 2268
# Model:                          Logit   Df Residuals:                     2264
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 04 Feb 2018   Pseudo R-squ.:                  -15.08
# Time:                        17:05:04   Log-Likelihood:                -12064.
# converged:                       True   LL-Null:                       -750.27
#                                         LLR p-value:                     1.000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Length             6.3563      2.024      3.140      0.002       2.389      10.324
# Diameter          -6.9861      2.609     -2.678      0.007     -12.099      -1.873
# Shucked_Weight     1.4576      0.481      3.032      0.002       0.516       2.400
# Viscera_Weight    -4.4339      1.010     -4.391      0.000      -6.413      -2.455
# ==================================================================================

# %% [markdown]
# ### Assessing Model Performance (train sample)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logreg = LogisticRegression()
logreg.fit(X2, y2)
logreg.score(X2, y2)
# Out:
# 0.56393298059964725

# %% [markdown]
# ### 4.1 Assessing Model Performance on Hold-Out Sample

# %%
from sklearn import metrics
logreg.fit(X2, y2)

X2_test = test[cols2]
y2_test = test['Gender_M']

Y2test_pred = logreg.predict(X2_test)
#print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X2_test, y2_test)))
logreg.score(X2_test, y2_test)
# Out:
# 0.544973544973545

# %% [markdown]
# Comparable out-of-sample performance indicates that there is little overfitting in on our training data.

# %% [markdown]
# ## 5. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

cols=["Length", "Diameter", "Height","Whole_Weight","Shucked_Weight","Viscera_Weight","Shell_Weight","Rings"] 
X=train[cols]
y=train['Gender_M']

random_forest = RandomForestClassifier(n_estimators=5)
random_forest.fit(X, y)
random_forest.score(X, y)
# Out:
# 0.95017636684303353

# %%
X_test=test[cols]
y_test=test['Gender_M']

random_forest = RandomForestClassifier(n_estimators=5)
random_forest.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# #### Well that's terrible out-of-sample performance. Let's try a decision tree.

# %% [markdown]
# ## 6. Decision Tree

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\sgus1\anaconda3\lib\site-packages

# %%
from sklearn import tree
import graphviz
tree1 = tree.DecisionTreeClassifier(criterion='gini', splitter='best',max_depth=3, min_samples_leaf=20)

# %%
tree1.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=20, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
import graphviz 
tree1_view = tree.export_graphviz(tree1, out_file=None, feature_names = X.columns.values, rotate=True) 
tree1viz = graphviz.Source(tree1_view)
#tree1viz

# %%
random_forest.predict(X)
random_forest.score(X, y)
# Out:
# 0.9528218694885362

# %%
tree1.predict(X_test)
tree1.score(X_test, y_test)
# Out:
# 0.53439153439153442

# %% [markdown]
# Again, siginificant deterioration in our out-of-sample testing.  The tree-based models (RF and Decision Tree) will require some fine tuning to improve their predictive power.
